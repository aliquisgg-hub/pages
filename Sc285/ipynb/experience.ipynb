# %% [markdown]
# # 試してみよう
# （「[ゼロからのPython入門講座 ― Python初体験](https://www.python.jp/train/experience/index.html)」から）
#
# ※ このファイルの内容は，「Python でこんなことができる」というショーケースのようなものなので，今の時点ではプログラムの記述のすべてが理解できなくてもよい．

# %%
# Code 1:

# # 左の「セルの実行」ボタン（▷）を押してみよう．
# （Jupyter Server の開始には少し時間がかかる）
# # から行末まで（緑色の文字の部分）はコメントなので，実行時には無視される．

print(1+1)  # 1+1 の計算結果を（下に）出力(print)する．
2+2         # Jupyter Notebook では，（コメント以外の）最後の「文」が値を持つ「式」の場合，その値も（下に）出力される．

# 下の出力結果を確認したら，その左の「3点メニュー」から「セルの出力をクリアする」を実行してみよう．

# %% [markdown]
# このファイルのような，拡張子 `.ipynb` のファイルは，Jupyter Notebook と呼ばれる形式である．
# Jupyter Notebook は，文章とプログラムを混在させて書くことができ，プログラムもファイル上で実行できる．
#
# Jupyter Notebook では，文章は<u>Markdownセル</u>に [Markdown記法](https://qiita.com/tbpgr/items/989c6badefff69377da7)
# と呼ばれる書き方で記述し，プログラムは<u>コードセル</u>に記述する．
#
# 下の2本の水平線の間（次のセルとの間）に，コードセルやMarkdownセルを，
#
# - 追加（セルの直下中央のボタン （マウスポインタが近づくと表示される），または左上のボタン），
# - 編集（テキストセルの編集の完了はセル右上のボタンから．再編集はダブルクリック），
# - 削除（セル右上のごみ箱アイコンをクリック）
#
# してみよう．
# ___

# %% [markdown]
# ___
# 以下のプログラム（「[ばえるPython](https://www.python.jp/train/experience/next-sample.html)」の1つ目の例を一部修正）を，下（水平線の上）にコードセルを作って実行してみよう．
# （コメント（# より右の部分）は含めなくてもよい）
#
# <div style="border:solid gray 1px; padding:1em;">
#
# ```python
# # Code 2:
#
# import io               # io ライブラリを読み込む（io.BytesIO などを使えるようにする）
# import requests         # requests ライブラリを読み込む（requests.get などを使えるようにする）
# from PIL import Image   # PIL ライブラリから Image モジュールを読み込む（Image.open などを使えるようにする）
#                         # `import PIL.Image` よりも標準的な書き方
#
# response = requests.get("https://www.python.jp/logo.png")   # URLからデータを取得する
# Image.open(io.BytesIO(response.content))                    # 取得したデータの内容を，画像オブジェクトにする
# ```
# </div>
#
# 最後の行は，画像オブジェクトを値とする「式」だが，Jupyter Notebook では，ノートブック内に表示される．
# 最後の行に `.show()` を付けて以下のようにして実行すると，Windows の画像ビューアが起動する．
# （これも試してみよう）
#
# <div style="border:solid gray 1px; padding:1em;">
#
# ```python
# Image.open(io.BytesIO(response.content)).show()
# ```
# </div>

# %% [markdown]
# ___
# このファイルと同じフォルダに適当な画像ファイル（仮に [`sample.jpg`](https://wwws.kobe-c.ac.jp/~miura/Sc285/sample.jpg) とする）をおいて，以下のプログラムを実行してみよう．
# （下（水平線の上）にコードセルを作って実行してみよう）
#
# <div style="border:solid gray 1px; padding:1em;">
#
# ```python
# # Code 3：
#
# from PIL import Image       # 実は，1度でも実行していたら，改めて実行する必要はない
# Image.open("sample.jpg")
# ```
#
# </div>
#
# ※ 同じフォルダの画像ファイルを表示するだけなら，`io` や `request` をインポートする必要はない．

# %% [markdown]
# ___
# 以下のプログラム（「[はたらくPython](https://www.python.jp/train/experience/next-sample2.html)」の例を一部修正）を，下（水平線の上）にコードセルを作って実行してみよう．
#
# <div style="border:solid gray 1px; padding:1em;">
#
# ```python
# # Code 4：
#
# import matplotlib.pyplot as plt     # matplotlib ライブラリの pyplot モジュールを plt という名で読み込む
#
# x_values = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June']  # 横軸のデータ（リスト）を変数 x_values に代入
# y_values = [100, 130, 80, 150, 140, 130]                # 縦軸のデータ（リスト）を変数 y_values に代入
#
# plt.bar(x_values, y_values)     # 棒グラフを構成して...
# plt.show()                      # 構成したグラフを表示する
# ```
#
# </div>
#
# 実行後に，上部の「変数」をクリックして，変数の内容も確認してみよう．

# %% [markdown]
# ___
# 以下のプログラム（オリジナル）を，下（水平線の上）にコードセルを作って実行してみよう．
#
# <div style="border:solid gray 1px; padding:1em;">
#
# ```python
# # Code 5：
#
# # メッセージ（文字列）を入力して，変数 message に入れる
# # Visual Studio Code のウィンドウの上部に入力窓が開く
# message = input("メッセージを入れてください．")
#
# # 変数 message の内容に空白を付けたものを2回繰り返して表示する．
# print((message + ' ') * 2)
# ```
#
# </div>

# %% [markdown]
# ___
# ## さらに...
#
# - 上の Code 1 ～ Code 5 を，それぞれ1つのファイル（拡張子は `.py`）に作成して，それぞれ実行してみよう．
#     - Visual Studio Code からは，右上の実行ボタンで実行できる（ウィンドウの下部にターミナルが開いて結果が表示される）．
#     - 最後の行が値を持つ「式」の場合，Jupyter Notebook のように，その値が表示されるわけではないので，Code 1 では `2+2` の結果は表示されない．
#     - 同様の理由で，Code 2，Code 3 も，`.show()` を付けた形でないと画像は表示されない．
#       - 画像ビューアなどの外部のプログラムを起動するプログラムは，（教室では）エクスプローラからファイルをダブルクリックしても実行できる．
# - このファイル（`experience.ipynb`）を，Google Colaboratory でも実行してみよう．
#     1. Google アカウントを用意する．
#     1. Google ドライブのマイドライブに，`Colab Notebooks` というフォルダを作成する．
#     1. `Colab Notebooks` に，書き込み前のこのファイル（`experience.ipynb`）をアップロードする．
#     1. アップロードした `experience.ipynb` をダブルクリックする．
