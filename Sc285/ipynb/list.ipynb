# %% [markdown]
# # オブジェクトとリスト
# ## リスト

# %%
stations = ["東京", "品川", "新横浜", "小田原", "熱海"]

# %%
print(stations)
# Out:
# ['東京', '品川', '新横浜', '小田原', '熱海']

# %%
cases = [100, 125, 110, 135, 93, 95, 93]
print(cases)
# Out:
# [100, 125, 110, 135, 93, 95, 93]

# %%
empty_list = []
print(empty_list)
# Out:
# []

# %%
print(stations[0])
# Out:
# 東京

# %%
print(stations[1])
# Out:
# 品川

# %%
print(stations[0], stations[1], stations[2], stations[3], stations[4])
# Out:
# 東京 品川 新横浜 小田原 熱海

# %%
stations[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\list.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/list.ipynb#ch0000009?line=0'>1</a> stations[5]
#
# IndexError: list index out of range

# %%
cases = [100, 125, 110, 135, 93, 95, 93]

total = cases[0] + cases[1] + cases[2] # ７日前から５日前までの感染者数の合計を求める
print(total)
# Out:
# 335

# %% [markdown]
# ## リストの操作

# %%
values = ['A', 'B', 'C']
print("修正前:", values)

values.insert(0, 999)
print("修正後:", values)
# Out:
# 修正前: ['A', 'B', 'C']
# 修正後: [999, 'A', 'B', 'C']

# %%
values = ['A', 'B', 'C']
print("修正前:", values)

values.insert(3, 999)
print("修正後:", values)
# Out:
# 修正前: ['A', 'B', 'C']
# 修正後: ['A', 'B', 'C', 999]

# %%
values = ['A', 'B', 'C']
print("修正前:", values)

values[1] = 'abc'
print("修正後:", values)
# Out:
# 修正前: ['A', 'B', 'C']
# 修正後: ['A', 'abc', 'C']

# %%
values = ['A', 'B', 'C']
values[3] = "D"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\list.ipynb Cell 15' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/list.ipynb#ch0000015?line=0'>1</a> values = ['A', 'B', 'C']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/list.ipynb#ch0000015?line=1'>2</a> values[3] = "D"
#
# IndexError: list assignment index out of range

# %%
values = ['A', 'B', 'C', 'D']
print("修正前:", values)

del values[1]
print("修正後:", values)
# Out:
# 修正前: ['A', 'B', 'C', 'D']
# 修正後: ['A', 'C', 'D']

# %% [markdown]
# ## while文を使ったリストのループ処理

# %%
cases = [100, 125, 110, 135, 93, 95, 93]
print(cases)
# Out:
# [100, 125, 110, 135, 93, 95, 93]

# %%
cases = [100, 125, 110, 135, 93, 95, 93]

index = 0 # インデックス値の初期値 0 を設定
total = 0 # 合計感染者数の初期値 0 を設定

while index < 7: # インデックス値 < 感染者数リストの要素数の間、ループを繰り返す
    cases_of_day = cases[index]
    total = total + cases_of_day # totalに、cases[index]を加算
    index = index + 1 # index に 1 を加算
    
print("合計感染者数は:", total)
# Out:
# 合計感染者数は: 751

# %%
cases = [100, 125, 110, 135, 93, 95, 93]

index = 0 # インデックス値の初期値 0 を設定
len_cases = len(cases)
total = 0 # 合計感染者数の初期値 0 を設定

while index < len_cases: # インデックス値 < len_cases の間、ループを繰り返す
    cases_of_day = cases[index]
    total = total + cases_of_day # totalに、cases[index]を加算
    index = index + 1 # index に 1 を加算
    
print("合計感染者数は:", total)
# Out:
# 合計感染者数は: 751

# %%
values = [1,2,3,4]  # 要素数4のリスト
print(len(values))
# Out:
# 4

# %% [markdown]
# ## for文によるループ

# %%
values = [1, 2, 3, 4]

for value in values:
    print("valueは", value, "value*valueは", value*value)
# Out:
# valueは 1 value*valueは 1
# valueは 2 value*valueは 4
# valueは 3 value*valueは 9
# valueは 4 value*valueは 16

# %%
values = [1, 2, 3, 4]
len_values = len(values) # valuesの要素数を求める

index = 0 # インデックス値の初期値 0 を設定

while index < len_values: # インデックス値 < len_values の間、ループを繰り返す
    value = values[index]
    print("valueは", value, "value*valueは", value*value)
    index = index + 1 # index に 1 を加算
# Out:
# valueは 1 value*valueは 1
# valueは 2 value*valueは 4
# valueは 3 value*valueは 9
# valueは 4 value*valueは 16

# %%
cases = [100, 125, 110, 135, 93, 95, 93]

index = 0 # インデックス値の初期値 0 を設定
len_cases = len(cases)
total = 0 # 合計感染者数の初期値 0 を設定

while index < len_cases: # インデックス値 < len_cases の間、ループを繰り返す
    cases_of_day = cases[index]
    total = total + cases_of_day # totalに、cases[index]を加算
    index = index + 1 # index に 1 を加算

print("合計感染者数は:", total)
# Out:
# 合計感染者数は: 751

# %%
cases = [100, 125, 110, 135, 93, 95, 93]

total = 0 # 合計感染者数の初期値 0 を設定
for cases_of_day in cases:
    total = total + cases_of_day

print("合計感染者数は:", total)
# Out:
# 合計感染者数は: 751
