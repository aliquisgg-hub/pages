# %% [markdown]
# # 文字列と入出力
# （元ファイルは[こちら](string2.ipynb)）

# %% [markdown]
#  ## 文字列

# %%
123
# Out:
# 123

# %%
456
# Out:
# 456

# %%
"Python Programming!"
# Out:
# 'Python Programming!'

# %%
'Python Programming!'
# Out:
# 'Python Programming!'

# %% [markdown]
# ### 文字と数字の違い

# %%
123 * 456
# Out:
# 56088

# %%
"123" * "456"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\string2.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000008?line=0'>1</a> "123" * "456"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# ## print() 関数

# %%
print(42)
# Out:
# 42

# %%
print(1,2,3)
# Out:
# 1 2 3

# %% [markdown]
# ### 文字列と print() 関数

# %%
print("もも5つと、みかん8つで", 100 * 5 + 40 * 8, "円になります。")
# Out:
# もも5つと、みかん8つで 820 円になります。

# %% [markdown]
# ## input() 関数

# %%
input("好きな文字を入力してください")
# Out:
# 'Hello!'

# %% [markdown]
# 次の例は、
#
# 1. <code>input()</code> 関数で入力した文字列を変数 <code>string</code> に代入し、
# 1. 変数 <code>string</code> を <code>print()</code>関数で出力します。

# %%
string = input("文字列を入力してください:")
print("文字列", string, "が入力されました。")
# Out:
# 文字列 Hello world! が入力されました。

# %% [markdown]
# ## 文字列の演算子と数値

# %%
123 + 456
# Out:
# 579

# %% [markdown]
# 文字列同士の足し算は、文字列の連結になります。文字列の <code>"123"</code> と <code>"456"</code> を足すと、<code>"123456"</code> になります。

# %%
"123" + "456"
# Out:
# '123456'

# %% [markdown]
# 数値と文字列を足すと、エラーになり、加算することはできません。

# %%
123 + "456"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\string2.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000023?line=0'>1</a> 123 + "456"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### 文字列の数値化

# %%
text = "123"
print(int(text))
# Out:
# 123

# %%
text1 = "123"
text2 = "456"

print(text1, "と", text2, "を足すと", int(text1) + int(text2), 'になります')
# Out:
# 123 と 456 を足すと 579 になります

# %%
text = "123.40"
float(text)
# Out:
# 123.4

# %% [markdown]
# 数字以外の文字は、数値にはできません。エラーになります。

# %%
int("Hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\string2.ipynb Cell 30' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000029?line=0'>1</a> int("Hello")
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# ### 数値の文字列化

# %%
num = 123
str(num)
# Out:
# '123'

# %%
height = 172   # height に 172を代入する
print("わたしの身長は " + str(height) + " cm です")
# Out:
# わたしの身長は 172 cm です

# %%
# 補足： 比べてみよう

height = 172   # height に 172を代入する
print("わたしの身長は", str(height), "cm です")
print("わたしの身長は", height, "cm です")
# Out:
# わたしの身長は 172 cm です
# わたしの身長は 172 cm です

# %% [markdown]
# ## メソッド

# %%
text = "lower letters" # 変数 text に 文字列 "lower letters"を代入
uppered_text = text.upper() # upper() メソッドで、大文字を作成
print(uppered_text)
# Out:
# LOWER LETTERS

# %% [markdown]
# データに結びついた関数のことを、メソッド と呼びます。メソッドは、次のように呼び出します。
#
# ```python
# データ.メソッド名(引数1, 引数2, 引数3, ...)
# ```

# %%
text = "lower letters" # 変数 text に 文字列 "lower letters"を代入
uppered_text = text.upper() # upper() メソッドで、大文字を作成

# %% [markdown]
# #### 文字列のfindメソッド

# %%
text = "The shells she sells are sea-shells, I'm sure."
text.find("sea")
# Out:
# 25

# %% [markdown]
# <code>find()</code> メソッドは、引数で指定した文字列が含まれていれば、その位置を戻り値として返します。この例では、<code>The shells she sells are sea-shells, I'm sure.</code> の、25番目の文字が <code>sea</code> となっています。(注:先頭の文字を0番目として数えて、25番目です。Pythonでは、順序は常に <code>0</code> から数えます。)

# %% [markdown]
# ### メソッドと関数

# %% [markdown]
# メソッドは **関数** の一種です。これまで見てきたように、特定のデータに結びつき、
#
# ```python
# データ.メソッド名()
# ```
# の形式で呼び出してデータを操作する関数を、メソッド と呼びます。
#
# メソッド は、結びついている データ を対象として、処理を行います。例えば、
#
# ```python
# "lower letters".upper()
# ```
#
# は、文字列データの <code>lower letters</code> に結び付けられた <code>upper()</code> メソッドを呼び出しています。<code>upper()</code> メソッドは、結びついているデータである <code>lower letters</code> を大文字に変換します。

# %% [markdown]
# ### メソッドとデータ

# %%
data = 10000
data.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\string2.ipynb Cell 45' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000044?line=0'>1</a> data = 10000
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000044?line=1'>2</a> data.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
data = 0.5
data.as_integer_ratio()
# Out:
# (1, 2)

# %%
data = "abracadabra"
data.as_integer_ratio()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\string2.ipynb Cell 47' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000046?line=0'>1</a> data = "abracadabra"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/string2.ipynb#ch0000046?line=1'>2</a> data.as_integer_ratio()
#
# AttributeError: 'str' object has no attribute 'as_integer_ratio'

# %% [markdown]
# ### 練習問題

# %% [markdown]
# #### 解答例

# %%
text = input("アルファベットを入力してください。")  # 変数 text に文章を入力
lower_text = text.lower()  # 入力した文字列を小文字に変換
print(text, "を小文字に変換すると、", lower_text, "になります。")
# Out:
# HELLO を小文字に変換すると、 hello になります。
