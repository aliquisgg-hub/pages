# %% [markdown]
# # import についての補足
#
# ```python
# from A import x, y, ...     # モジュール A から x, y, ... をインポートする
# ```
#
# - `x`, `y` の呼び出しは，`A.x` や `A.y` のように，`A.` を付けなくてもよい
# - `x`, `y` ... 以外はインポートされない
#   - 通常の `import A` の場合は，`A` で定義されているすべてがインポートされる

# %%
# モジュール math から sqrt（平方根関数）をインポートする
from math import sqrt
sqrt(3)     # math. を付けなくてもよい
# Out:
# 1.7320508075688772

# %%
# モジュール math から cos（余弦関数）と pi（円周率）をインポートする
from math import cos, pi
print(cos(pi/3))
print(sin(pi/3))    # sin はインポートしていないのでエラーになる
# Out:
# 0.5000000000000001
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\miura\Documents\wwws\Sc285\ipynb\tafPlus2.ipynb Cell 3' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/tafPlus2.ipynb#ch0000002?line=1'>2</a> from math import cos, pi
#       <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/tafPlus2.ipynb#ch0000002?line=2'>3</a> print(cos(pi/3))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miura/Documents/wwws/Sc285/ipynb/tafPlus2.ipynb#ch0000002?line=3'>4</a> print(sin(pi/3))
#
# NameError: name 'sin' is not defined

# %%
# こうすれば大丈夫
from math import sin, cos, pi
print(cos(pi/3))
print(sin(pi/3))
# Out:
# 0.5000000000000001
# 0.8660254037844386

# %% [markdown]
# ```python
# import A as B       # モジュール A を B という名前でインポートする
# ```

# %%
import matplotlib.pyplot as plt
plt.bar(['A', 'B', 'C'], [1, 3, 2])
plt.show()

# %%
# こう書くよりも大分楽
import matplotlib.pyplot
matplotlib.pyplot.bar(['A', 'B', 'C'], [1, 3, 2])
matplotlib.pyplot.show()

# %% [markdown]
# - `as` の後の名前は自由に付けられるが，あまり勝手につけると，
#   第三者が読みづらくなったり，後で読む際にどのモジュールだったかわからなくなったりする．
# - なので，慣習的に標準が定まっているものは，その慣習に従うのがよい．
# - 上の例の `matplotlib.pyplot` を `plt` と名付けるのも，慣習的な標準になっている．
