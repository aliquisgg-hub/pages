# %%
import pandas as pd
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"], index=[1001,1002,1003])
df
# Out:
#       A  B  C
# 1001  1  2  3
# 1002  4  5  6
# 1003  7  8  9

# %%
display(df["B"])
display(df[["B"]])
display(df[["A","C"]])
display(df[["C","A"]])
# Out:
# 1001    2
# 1002    5
# 1003    8
# Name: B, dtype: int64
#       B
# 1001  2
# 1002  5
# 1003  8
#       A  C
# 1001  1  3
# 1002  4  6
# 1003  7  9
#       C  A
# 1001  3  1
# 1002  6  4
# 1003  9  7

# %%
display(df.loc[1001])
display(df.iloc[1])
# Out:
# A    1
# B    2
# C    3
# Name: 1001, dtype: int64
# A    4
# B    5
# C    6
# Name: 1002, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# y:\Documents\wwws\Sc288\ipynb\pandas.ipynb セル 4 in <module>
# ----> <a href='vscode-notebook-cell:/y%3A/Documents/wwws/Sc288/ipynb/pandas.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df.reverse()
#
# File c:\ProgramData\Miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reverse'
