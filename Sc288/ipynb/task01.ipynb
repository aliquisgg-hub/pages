# %% [markdown]
# # 第1週課題

# %% [markdown]
# Ⅰ. 底面の半径を $r$，高さを $h$ としたときの円錐の体積を計算する式を書くこと
# - 半径の $r$，高さの $h$ は，それぞれ変数 `r`, `h` で，あらかじめ与える
#   - この課題では，$r=10,\ h=10$ で計算した結果を示すこと
# - 円周率 $\pi$ は `math` をインポートして `math.pi` を用いること
# - 円錐の体積の求め方は自分で調べること
# - 計算式は末尾に書いて，結果を表示させること

# %%
r = 10; h = 10

# %% [markdown]
# Ⅱ. $a,b,c$ の相乗平均 $\sqrt[3]{a×b×c}$ を計算する式を書くこと
# - $a,b,c$ は，それぞれ変数 `a`, `b`, `c` で，あらかじめ与える
#   - この課題では，$a=4,\ b=6,\ c=9$ で計算した結果を示すこと
# - $x$ の立方根 $\sqrt[3]{x}$ は，$x$ の $\frac13$ 乗に等しいことを用いるとよい
# - 計算式は末尾に書いて，結果を表示させること

# %%
a=4; b=6; c=9
